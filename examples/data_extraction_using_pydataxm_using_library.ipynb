# %% [markdown]
# # Objetivos de este Notebook
#
# * Explicar cómo se realiza la instalación del pydataxm desde la consola para su uso en ambientes locales
# * Explicar cómo se pueden consultar las métricas que se encuentran disponibles en el servicio
# * Explicar cómo consultar una variable determinada
# * Explicar cómo consultar una variable determinada usando filtros
#
# **Índice**
#
# 1. [Instalación de librerías](#section1)
#
# 2. [Importación de librerías](#section2)
#
# 3. [Método para conocer los cruces existentes de una métrica](#section3)
#
# 4. [Consultar variables](#section4)
#
# 5. [Consultar variables usando filtros](#section5)

# %% [markdown]
# <a id='section1'></a>
# # Instalación de la librería
# Ejecutar el siguiente comando en el CMD para instalar la librería de python

# %%
#!pip install pydataxm

# %% [markdown]
# <a id='section2'></a>
# # Importación de librerías

# %%
from pydataxm import *                           #Se realiza la importación de las librerias necesarias para ejecutar
import datetime as dt                            
from pydataxm.pydataxm import ReadDB as apiXM    #Se importa la clase que invoca el servicio

# %%
objetoAPI = pydataxm.ReadDB()                    #Se almacena el servicio en el nombre objetoAPI

# %%
df = apiXM.request_data(pydataxm.ReadDB(),       #Se indica el objeto que contiene el serivicio
                        "ListadoMetricas",       #Se indica el nombre de la métrica tal como se llama en el campo metricID
                        0,                       #Campo númerico indicando el nivel de desagregación, 0 para valores del Sistema
                        dt.date(2021, 1, 1),     #Corresponde a la fecha inicial de la consulta
                        dt.date(2021, 1, 10))    #Corresponde a la fecha final de la consulta

# %%
df
# Out:
#          Id  Values_MetricId  \
# 0   Sistema         DemaCome
# 1   Sistema             Gene
# 2   Sistema         GeneIdea
# 3   Sistema     PrecBolsNaci
# 4   Sistema         RestAliv
# ..      ...              ...
# 73  Sistema  ListadoRecursos
# 74  Sistema  ListadoRecursos
# 75  Sistema   ListadoAgentes
# 76  Sistema      ListadoRios
# 77  Sistema  ListadoEmbalses
#
#                                    Values_MetricName Values_Entity  \
# 0                                  Demanda Comercial       Sistema
# 1                                         Generación       Sistema
# 2                                   Generación Ideal       Sistema
# 3                              Precio Bolsa Nacional       Sistema
# 4                            Restricciones Aliviadas       Sistema
# ..                                               ...           ...
# 73  plantas y unidades que tiene asociadas un agente        Agente
# 74                    Listado Recursos con atributos       Sistema
# 75                  Listado de agentes con atributos       Sistema
# 76                                   Listado de rios       Sistema
# 77                               Listado de embalses       Sistema
#
#     Values_MaxDays     Values_Type                         Values_Url  \
# 0               31  HourlyEntities  http://servapibi.xm.com.co/hourly
# 1               31  HourlyEntities  http://servapibi.xm.com.co/hourly
# 2               31  HourlyEntities  http://servapibi.xm.com.co/hourly
# 3               31  HourlyEntities  http://servapibi.xm.com.co/hourly
# 4               31  HourlyEntities  http://servapibi.xm.com.co/hourly
# ..             ...             ...                                ...
# 73             731   ListsEntities    http://servapibi.xm.com.co/list
# 74             731   ListsEntities    http://servapibi.xm.com.co/list
# 75             731   ListsEntities    http://servapibi.xm.com.co/list
# 76             731   ListsEntities    http://servapibi.xm.com.co/list
# 77             731   ListsEntities    http://servapibi.xm.com.co/list
#
#    Values_Filter       Date
# 0      No aplica 2021-09-09
# 1      No aplica 2021-09-09
# 2      No aplica 2021-09-09
# 3      No aplica 2021-09-09
# 4      No aplica 2021-09-09
# ..           ...        ...
# 73     No aplica 2021-09-09
# 74     No aplica 2021-09-09
# 75     No aplica 2021-09-09
# 76     No aplica 2021-09-09
# 77     No aplica 2021-09-09
#
# [78 rows x 9 columns]

# %% [markdown]
# <a id='section3'></a>
# # Método para conocer los cruces existentes de una métrica

# %%
df =objetoAPI.get_collections("GeneIdea")   
df
# Out:
# [[0, 'Generacion Ideal', 'Sistema', 'Horaria'],
#  [1, 'Generacion Ideal', 'Recurso', 'Horaria']]

# %% [markdown]
# <a id='section4'></a>
# # Consultar variables

# %%
df = apiXM.request_data(pydataxm.ReadDB(),    #Se indica el objeto que contiene el serivicio
                        "Gene",           #Se indica el nombre de la métrica tal como se llama en el campo metricID
                        1,                    #Campo númerico indicando el nivel de desagregación, 1 para valores por Recurso
                        dt.date(2021, 1, 1),  #Corresponde a la fecha inicial de la consulta
                        dt.date(2021, 1, 10)) #Corresponde a la fecha final de la consulta

df.head(5)                                    #Observar el encabezado del DataFrame extraido
# Out:
#         Id Values_code  Values_Hour01  Values_Hour02  Values_Hour03  \
# 0  Recurso        2QBW       19932.61       19903.54       19936.70
# 1  Recurso        2QRL         669.63         669.18         668.61
# 2  Recurso        2QV2       18928.80       18932.40       18939.60
# 3  Recurso        2R22       10233.27       10234.12       10228.39
# 4  Recurso        2S6Q            NaN            NaN            NaN
#
#    Values_Hour04  Values_Hour05  Values_Hour06  Values_Hour07  Values_Hour08  \
# 0       19934.60       19925.70       19926.82       19932.70       19928.81
# 1         669.51         669.39         669.27         669.27         669.15
# 2       18936.00       18939.60       18745.20       18381.60       18367.20
# 3       10237.70       10239.17       10230.93       10228.58       10237.20
# 4            NaN            NaN            NaN            NaN            NaN
#
#    ...  Values_Hour16  Values_Hour17  Values_Hour18  Values_Hour19  \
# 0  ...       18730.21       18707.29       18562.60       18364.80
# 1  ...         668.79         669.36         669.42         669.18
# 2  ...       16473.60       16470.00       16484.40       16480.80
# 3  ...       13724.14       13733.41       13721.49       13708.83
# 4  ...            NaN            NaN            NaN            NaN
#
#    Values_Hour20  Values_Hour21  Values_Hour22  Values_Hour23  Values_Hour24  \
# 0       18210.10       18067.77       17949.09       17859.62       17702.52
# 1         669.18         577.83         669.75         670.20         670.05
# 2       16477.20       16603.20       17096.40       17146.80       17143.20
# 3       13722.02       13718.90       13723.54        7833.53        2584.50
# 4           6.00            NaN            NaN            NaN            NaN
#
#         Date
# 0 2021-01-01
# 1 2021-01-01
# 2 2021-01-01
# 3 2021-01-01
# 4 2021-01-01
#
# [5 rows x 27 columns]

# %%
df = apiXM.request_data(pydataxm.ReadDB(),    #Se indica el objeto que contiene el serivicio
                        "RestAliv",           #Se indica el nombre de la métrica tal como se llama en el campo metricID
                        0,                    #Campo númerico indicando el nivel de desagregación, 0 para valores por Sistema
                        dt.date(2020, 1, 1),  #Corresponde a la fecha inicial de la consulta
                        dt.date(2021, 7, 10)) #Corresponde a la fecha final de la consulta
df.head(5)
# Out:
#         Id Values_code  Values_Hour01  Values_Hour02  Values_Hour03  \
# 0  Sistema     Sistema   1.172154e+08   8.660295e+07   9.300140e+07
# 1  Sistema     Sistema   3.638374e+07   4.233913e+07   1.036974e+08
# 2  Sistema     Sistema   4.855051e+07   5.423334e+07   5.785956e+07
# 3  Sistema     Sistema   1.275839e+08   1.415680e+08   1.633067e+08
# 4  Sistema     Sistema   2.859453e+07   7.546626e+07   7.564020e+07
#
#    Values_Hour04  Values_Hour05  Values_Hour06  Values_Hour07  Values_Hour08  \
# 0   1.066055e+08   1.353072e+08   1.455932e+08    90371045.50    77149839.10
# 1   1.093193e+08   1.040239e+08   1.003533e+08    97423605.24    91660213.47
# 2   6.300535e+07   6.554569e+07   6.456615e+07    95640000.11    31133047.90
# 3   1.655610e+08   1.182684e+08   6.507056e+07    75528244.41    69352843.82
# 4   8.285122e+07   9.986535e+07   6.164114e+07    35043247.57    46082707.31
#
#    ...  Values_Hour16  Values_Hour17  Values_Hour18  Values_Hour19  \
# 0  ...    92445044.18   1.150948e+08   1.816433e+08   1.118835e+08
# 1  ...    -6399408.30  -3.961031e+06   2.060385e+07  -2.085450e+07
# 2  ...    22566778.08   2.386321e+07   2.525195e+07   1.869876e+07
# 3  ...    53583680.25   6.821480e+07   9.520386e+07   9.846094e+07
# 4  ...    47300831.09   7.015762e+07   7.995634e+07   4.997135e+07
#
#    Values_Hour20  Values_Hour21  Values_Hour22  Values_Hour23  Values_Hour24  \
# 0  -7.845004e+07    74500276.65    59795477.21    48373992.96   9.715393e+07
# 1  -2.139210e+07   -10824906.78    22346934.10    26288664.90   9.190016e+06
# 2   2.313837e+07    35770466.44    34458315.82    29900035.32   3.126118e+07
# 3   1.035620e+08    81797288.87    82854469.76    68453292.09   1.905770e+08
# 4   5.095019e+07    47600045.23    50988876.88    35312426.14   9.431308e+07
#
#         Date
# 0 2020-01-01
# 1 2020-01-02
# 2 2020-01-03
# 3 2020-01-04
# 4 2020-01-05
#
# [5 rows x 27 columns]

# %% [markdown]
# # Consultar variables usando filtros

# %%
df = apiXM.request_data(pydataxm.ReadDB(),    #Se indica el objeto que contiene el serivicio
                        "Gene",           #Se indica el nombre de la métrica tal como se llama en el campo metricID
                        1,                    #Campo númerico indicando el nivel de desagregación, 0 para valores por Sistema
                        dt.date(2020, 1, 1),  #Corresponde a la fecha inicial de la consulta
                        dt.date(2021, 7, 10), #Corresponde a la fecha final de la consulta
                        filtros =['EPFV','JEP1','TR3G']) #Se indican los códigos SIC de plantas dentro de una lista
df
# Out:
#           Id Values_code  Values_Hour01  Values_Hour02  Values_Hour03  \
# 0    Recurso        EPFV            NaN            NaN            NaN
# 1    Recurso        EPFV            NaN            NaN            NaN
# 2    Recurso        EPFV            NaN            NaN            NaN
# 3    Recurso        EPFV            NaN            NaN            NaN
# 4    Recurso        EPFV            NaN            NaN            NaN
# ..       ...         ...            ...            ...            ...
# 795  Recurso        TR3G            NaN            NaN            NaN
# 796  Recurso        EPFV            NaN            NaN            NaN
# 797  Recurso        TR3G            NaN            NaN            NaN
# 798  Recurso        EPFV            NaN            NaN            NaN
# 799  Recurso        TR3G            NaN            NaN            NaN
#
#      Values_Hour04  Values_Hour05  Values_Hour06  Values_Hour07  \
# 0              NaN            NaN            NaN        2261.75
# 1              NaN            NaN            NaN        3135.59
# 2              NaN            NaN            NaN        2765.44
# 3              NaN            NaN            NaN        3079.03
# 4              NaN            NaN            NaN        1625.79
# ..             ...            ...            ...            ...
# 795            NaN            NaN            NaN        1050.44
# 796            NaN            NaN          17.38        7139.34
# 797            NaN            NaN            NaN         643.53
# 798            NaN            NaN            NaN        2806.25
# 799            NaN            NaN           1.69        1610.96
#
#      Values_Hour08  ...  Values_Hour16  Values_Hour17  Values_Hour18  \
# 0         20316.48  ...       34184.30       21763.99        1698.27
# 1         27257.06  ...       42770.16       23111.03        2332.84
# 2         27207.75  ...       42316.74       21719.60        2358.57
# 3         29186.94  ...       41792.00       27243.19        2466.01
# 4         11617.17  ...       43828.05       24765.34        3024.19
# ..             ...  ...            ...            ...            ...
# 795        4250.79  ...       12847.77        7914.46         630.07
# 796       31888.47  ...       39792.15       10710.01        2860.11
# 797        1286.84  ...        3575.68        2223.36         709.76
# 798        8218.62  ...       11163.70        6946.11        3069.20
# 799        2969.03  ...        3124.30        2456.45        1469.62
#
#      Values_Hour19  Values_Hour20  Values_Hour21  Values_Hour22  \
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 2              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 795            NaN            NaN            NaN            NaN
# 796            NaN            NaN            NaN            NaN
# 797            NaN            NaN            NaN            NaN
# 798            NaN            NaN            NaN            NaN
# 799            NaN            NaN            NaN            NaN
#
#      Values_Hour23  Values_Hour24       Date
# 0              NaN            NaN 2020-01-01
# 1              NaN            NaN 2020-01-02
# 2              NaN            NaN 2020-01-03
# 3              NaN            NaN 2020-01-04
# 4              NaN            NaN 2020-01-05
# ..             ...            ...        ...
# 795            NaN            NaN 2021-07-08
# 796            NaN            NaN 2021-07-09
# 797            NaN            NaN 2021-07-09
# 798            NaN            NaN 2021-07-10
# 799            NaN            NaN 2021-07-10
#
# [800 rows x 27 columns]
